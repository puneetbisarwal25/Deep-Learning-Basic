# %% [markdown]
# <a href="https://colab.research.google.com/github/puneetbisarwal25/Deep-Learning-Basic/blob/main/gan_pytorchipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Step 1: Importing Required Libraries

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
import numpy as np

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# ## Step 2: Defining Image Transformations

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# %% [markdown]
# ## Step 3: Loading the CIFAR-10 Dataset

# %%
train_dataset = datasets.CIFAR10(root='./data',\
              train=True, download=True, transform=transform)
dataloader = torch.utils.data.DataLoader(train_dataset, \
                                batch_size=32, shuffle=True)
# Out:
# 100%|██████████| 170M/170M [02:18<00:00, 1.23MB/s]

# %% [markdown]
# ## Step 4: Defining GAN Hyperparameters

# %%
latent_dim = 100
lr = 0.0002
beta1 = 0.5
beta2 = 0.999
num_epochs = 10

# %% [markdown]
# ## Step 5: Building the Generator

# %%
class Generator(nn.Module):
    def __init__(self, latent_dim):
        super(Generator, self).__init__()

        self.model = nn.Sequential(
            nn.Linear(latent_dim, 128 * 8 * 8),
            nn.ReLU(),
            nn.Unflatten(1, (128, 8, 8)),
            nn.Upsample(scale_factor=2),
            nn.Conv2d(128, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128, momentum=0.78),
            nn.ReLU(),
            nn.Upsample(scale_factor=2),
            nn.Conv2d(128, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64, momentum=0.78),
            nn.ReLU(),
            nn.Conv2d(64, 3, kernel_size=3, padding=1),
            nn.Tanh()
        )

    def forward(self, z):
        img = self.model(z)
        return img

# %% [markdown]
# ## Step 6: Building the Discriminator

# %%
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()

        self.model = nn.Sequential(
        nn.Conv2d(3, 32, kernel_size=3, stride=2, padding=1),
        nn.LeakyReLU(0.2),
        nn.Dropout(0.25),
        nn.Conv2d(32, 64, kernel_size=3, stride=2, padding=1),
        nn.ZeroPad2d((0, 1, 0, 1)),
        nn.BatchNorm2d(64, momentum=0.82),
        nn.LeakyReLU(0.25),
        nn.Dropout(0.25),
        nn.Conv2d(64, 128, kernel_size=3, stride=2, padding=1),
        nn.BatchNorm2d(128, momentum=0.82),
        nn.LeakyReLU(0.2),
        nn.Dropout(0.25),
        nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1),
        nn.BatchNorm2d(256, momentum=0.8),
        nn.LeakyReLU(0.25),
        nn.Dropout(0.25),
        nn.Flatten(),
        nn.Linear(256 * 5 * 5, 1),
        nn.Sigmoid()
    )

    def forward(self, img):
        validity = self.model(img)
        return validity

# %% [markdown]
# ## Step 7: Initializing GAN Components

# %%
generator = Generator(latent_dim).to(device)
discriminator = Discriminator().to(device)
adversarial_loss = nn.BCELoss()

optimizer_G = optim.Adam(generator.parameters()\
                         , lr=lr, betas=(beta1, beta2))
optimizer_D = optim.Adam(discriminator.parameters()\
                         , lr=lr, betas=(beta1, beta2))

# %% [markdown]
# ## Step 8: Training the GAN

# %%
for epoch in range(num_epochs):
    for i, batch in enumerate(dataloader):
        real_images = batch[0].to(device)

        valid = torch.ones(real_images.size(0), 1, device=device)
        fake = torch.zeros(real_images.size(0), 1, device=device)

        real_images = real_images.to(device)

        optimizer_D.zero_grad()

        z = torch.randn(real_images.size(0), latent_dim, device=device)

        fake_images = generator(z)

        real_loss = adversarial_loss(discriminator\
                                     (real_images), valid)
        fake_loss = adversarial_loss(discriminator\
                                     (fake_images.detach()), fake)
        d_loss = (real_loss + fake_loss) / 2

        d_loss.backward()
        optimizer_D.step()

        optimizer_G.zero_grad()

        gen_images = generator(z)

        g_loss = adversarial_loss(discriminator(gen_images), valid)

        g_loss.backward()
        optimizer_G.step()

        if (i + 1) % 100 == 0:
            print(
                f"Epoch [{epoch+1}/{num_epochs}]\
                        Batch {i+1}/{len(dataloader)} "
                f"Discriminator Loss: {d_loss.item():.4f} "
                f"Generator Loss: {g_loss.item():.4f}"
            )
    if (epoch + 1) % 10 == 0:
        with torch.no_grad():
            z = torch.randn(16, latent_dim, device=device)
            generated = generator(z).detach().cpu()
            grid = torchvision.utils.make_grid(generated,\
                                        nrow=4, normalize=True)
            plt.imshow(np.transpose(grid, (1, 2, 0)))
            plt.axis("off")
            plt.show()
# Out:
# Epoch [1/10]                        Batch 100/1563 Discriminator Loss: 0.5257 Generator Loss: 1.4968
# Epoch [1/10]                        Batch 200/1563 Discriminator Loss: 0.7531 Generator Loss: 0.9376
# Epoch [1/10]                        Batch 300/1563 Discriminator Loss: 0.6723 Generator Loss: 0.9407
# Epoch [1/10]                        Batch 400/1563 Discriminator Loss: 0.5303 Generator Loss: 0.8542
# Epoch [1/10]                        Batch 500/1563 Discriminator Loss: 0.5442 Generator Loss: 1.2115
# Epoch [1/10]                        Batch 600/1563 Discriminator Loss: 0.5609 Generator Loss: 1.2000
# Epoch [1/10]                        Batch 700/1563 Discriminator Loss: 0.6144 Generator Loss: 0.8585
# Epoch [1/10]                        Batch 800/1563 Discriminator Loss: 0.6400 Generator Loss: 1.1861
# Epoch [1/10]                        Batch 900/1563 Discriminator Loss: 0.7459 Generator Loss: 0.8628
# Epoch [1/10]                        Batch 1000/1563 Discriminator Loss: 0.7274 Generator Loss: 0.8393
# Epoch [1/10]                        Batch 1100/1563 Discriminator Loss: 0.6051 Generator Loss: 1.0980
# Epoch [1/10]                        Batch 1200/1563 Discriminator Loss: 0.7466 Generator Loss: 0.8622
# Epoch [1/10]                        Batch 1300/1563 Discriminator Loss: 0.5375 Generator Loss: 1.1897
# Epoch [1/10]                        Batch 1400/1563 Discriminator Loss: 0.6089 Generator Loss: 0.8643
# Epoch [1/10]                        Batch 1500/1563 Discriminator Loss: 0.6227 Generator Loss: 0.9960
# Epoch [2/10]                        Batch 100/1563 Discriminator Loss: 0.7350 Generator Loss: 0.7316
# Epoch [2/10]                        Batch 200/1563 Discriminator Loss: 0.8030 Generator Loss: 0.5498
# Epoch [2/10]                        Batch 300/1563 Discriminator Loss: 0.5362 Generator Loss: 0.8809
# Epoch [2/10]                        Batch 400/1563 Discriminator Loss: 0.6260 Generator Loss: 0.9536
# Epoch [2/10]                        Batch 500/1563 Discriminator Loss: 0.7453 Generator Loss: 0.8012
# Epoch [2/10]                        Batch 600/1563 Discriminator Loss: 0.4654 Generator Loss: 1.2783
# Epoch [2/10]                        Batch 700/1563 Discriminator Loss: 0.6981 Generator Loss: 0.9833
# Epoch [2/10]                        Batch 800/1563 Discriminator Loss: 0.6939 Generator Loss: 1.4513
# Epoch [2/10]                        Batch 900/1563 Discriminator Loss: 0.6359 Generator Loss: 1.1693
# Epoch [2/10]                        Batch 1000/1563 Discriminator Loss: 0.5648 Generator Loss: 1.2368
# Epoch [2/10]                        Batch 1100/1563 Discriminator Loss: 0.5483 Generator Loss: 1.3010
# Epoch [2/10]                        Batch 1200/1563 Discriminator Loss: 0.6508 Generator Loss: 0.8277
# Epoch [2/10]                        Batch 1300/1563 Discriminator Loss: 0.5526 Generator Loss: 0.8359
# Epoch [2/10]                        Batch 1400/1563 Discriminator Loss: 0.4765 Generator Loss: 0.9817
# Epoch [2/10]                        Batch 1500/1563 Discriminator Loss: 0.5740 Generator Loss: 1.0970
# Epoch [3/10]                        Batch 100/1563 Discriminator Loss: 0.5865 Generator Loss: 0.8884
# Epoch [3/10]                        Batch 200/1563 Discriminator Loss: 0.5104 Generator Loss: 1.0770
# Epoch [3/10]                        Batch 300/1563 Discriminator Loss: 0.5452 Generator Loss: 1.7740
# Epoch [3/10]                        Batch 400/1563 Discriminator Loss: 0.7386 Generator Loss: 1.4638
# Epoch [3/10]                        Batch 500/1563 Discriminator Loss: 0.7113 Generator Loss: 1.1508
# Epoch [3/10]                        Batch 600/1563 Discriminator Loss: 0.5312 Generator Loss: 1.1549
# Epoch [3/10]                        Batch 700/1563 Discriminator Loss: 0.4890 Generator Loss: 2.1519
# Epoch [3/10]                        Batch 800/1563 Discriminator Loss: 0.4558 Generator Loss: 1.1616
# Epoch [3/10]                        Batch 900/1563 Discriminator Loss: 0.5473 Generator Loss: 1.4182
# Epoch [3/10]                        Batch 1000/1563 Discriminator Loss: 0.4339 Generator Loss: 1.4990
# Epoch [3/10]                        Batch 1100/1563 Discriminator Loss: 0.5107 Generator Loss: 1.0019
# Epoch [3/10]                        Batch 1200/1563 Discriminator Loss: 0.6092 Generator Loss: 1.1746
# Epoch [3/10]                        Batch 1300/1563 Discriminator Loss: 0.4460 Generator Loss: 1.3204
# Epoch [3/10]                        Batch 1400/1563 Discriminator Loss: 0.5655 Generator Loss: 2.0192
# Epoch [3/10]                        Batch 1500/1563 Discriminator Loss: 0.7165 Generator Loss: 1.1202
# Epoch [4/10]                        Batch 100/1563 Discriminator Loss: 0.6035 Generator Loss: 1.2217
# Epoch [4/10]                        Batch 200/1563 Discriminator Loss: 0.6462 Generator Loss: 1.3338
# Epoch [4/10]                        Batch 300/1563 Discriminator Loss: 0.5453 Generator Loss: 1.4910
# Epoch [4/10]                        Batch 400/1563 Discriminator Loss: 0.4787 Generator Loss: 1.0271
# Epoch [4/10]                        Batch 500/1563 Discriminator Loss: 0.6943 Generator Loss: 1.3296
# Epoch [4/10]                        Batch 600/1563 Discriminator Loss: 0.6235 Generator Loss: 0.8854
# Epoch [4/10]                        Batch 700/1563 Discriminator Loss: 0.4330 Generator Loss: 1.2216
# Epoch [4/10]                        Batch 800/1563 Discriminator Loss: 0.6337 Generator Loss: 1.2269
# Epoch [4/10]                        Batch 900/1563 Discriminator Loss: 0.5819 Generator Loss: 0.9056
# Epoch [4/10]                        Batch 1000/1563 Discriminator Loss: 0.6476 Generator Loss: 1.1819
# Epoch [4/10]                        Batch 1100/1563 Discriminator Loss: 0.5701 Generator Loss: 1.3762
# Epoch [4/10]                        Batch 1200/1563 Discriminator Loss: 0.6393 Generator Loss: 1.4406
# Epoch [4/10]                        Batch 1300/1563 Discriminator Loss: 0.5688 Generator Loss: 1.6183
# Epoch [4/10]                        Batch 1400/1563 Discriminator Loss: 0.5156 Generator Loss: 1.5011
# Epoch [4/10]                        Batch 1500/1563 Discriminator Loss: 0.8584 Generator Loss: 1.2251
# Epoch [5/10]                        Batch 100/1563 Discriminator Loss: 0.6176 Generator Loss: 1.1425
# Epoch [5/10]                        Batch 200/1563 Discriminator Loss: 0.6907 Generator Loss: 0.9263
# Epoch [5/10]                        Batch 300/1563 Discriminator Loss: 0.7821 Generator Loss: 1.4778
# Epoch [5/10]                        Batch 400/1563 Discriminator Loss: 0.5377 Generator Loss: 1.7179
# Epoch [5/10]                        Batch 500/1563 Discriminator Loss: 0.6415 Generator Loss: 1.0483
# Epoch [5/10]                        Batch 600/1563 Discriminator Loss: 0.7742 Generator Loss: 2.2151
# Epoch [5/10]                        Batch 700/1563 Discriminator Loss: 0.8176 Generator Loss: 1.0999
# Epoch [5/10]                        Batch 800/1563 Discriminator Loss: 0.5737 Generator Loss: 0.8150
# Epoch [5/10]                        Batch 900/1563 Discriminator Loss: 0.5192 Generator Loss: 1.4058
# Epoch [5/10]                        Batch 1000/1563 Discriminator Loss: 0.4675 Generator Loss: 1.2822
# Epoch [5/10]                        Batch 1100/1563 Discriminator Loss: 0.7154 Generator Loss: 1.2219
# Epoch [5/10]                        Batch 1200/1563 Discriminator Loss: 0.6385 Generator Loss: 1.0363
# Epoch [5/10]                        Batch 1300/1563 Discriminator Loss: 0.9272 Generator Loss: 0.7860
# Epoch [5/10]                        Batch 1400/1563 Discriminator Loss: 0.7499 Generator Loss: 0.7500
# Epoch [5/10]                        Batch 1500/1563 Discriminator Loss: 0.6075 Generator Loss: 1.3051
# Epoch [6/10]                        Batch 100/1563 Discriminator Loss: 0.5521 Generator Loss: 0.8450
# Epoch [6/10]                        Batch 200/1563 Discriminator Loss: 0.5572 Generator Loss: 1.2673
# Epoch [6/10]                        Batch 300/1563 Discriminator Loss: 0.8693 Generator Loss: 0.9892
# Epoch [6/10]                        Batch 400/1563 Discriminator Loss: 0.6054 Generator Loss: 0.8956
# Epoch [6/10]                        Batch 500/1563 Discriminator Loss: 0.5260 Generator Loss: 1.6272
# Epoch [6/10]                        Batch 600/1563 Discriminator Loss: 0.4066 Generator Loss: 1.6637
# Epoch [6/10]                        Batch 700/1563 Discriminator Loss: 0.6588 Generator Loss: 1.2153
# Epoch [6/10]                        Batch 800/1563 Discriminator Loss: 0.4592 Generator Loss: 1.4392
# Epoch [6/10]                        Batch 900/1563 Discriminator Loss: 0.6788 Generator Loss: 1.2527
# Epoch [6/10]                        Batch 1000/1563 Discriminator Loss: 0.5386 Generator Loss: 1.3903
# Epoch [6/10]                        Batch 1100/1563 Discriminator Loss: 0.6626 Generator Loss: 1.1401
# Epoch [6/10]                        Batch 1200/1563 Discriminator Loss: 0.4840 Generator Loss: 1.3814
# Epoch [6/10]                        Batch 1300/1563 Discriminator Loss: 0.7590 Generator Loss: 1.0809
# Epoch [6/10]                        Batch 1400/1563 Discriminator Loss: 0.5788 Generator Loss: 0.8395
# Epoch [6/10]                        Batch 1500/1563 Discriminator Loss: 0.5672 Generator Loss: 1.9489
# Epoch [7/10]                        Batch 100/1563 Discriminator Loss: 0.6342 Generator Loss: 1.5319
# Epoch [7/10]                        Batch 200/1563 Discriminator Loss: 0.6071 Generator Loss: 1.2963
# Epoch [7/10]                        Batch 300/1563 Discriminator Loss: 0.6709 Generator Loss: 1.1291
# Epoch [7/10]                        Batch 400/1563 Discriminator Loss: 0.7143 Generator Loss: 1.2714
# Epoch [7/10]                        Batch 500/1563 Discriminator Loss: 0.5978 Generator Loss: 1.0001
# Epoch [7/10]                        Batch 600/1563 Discriminator Loss: 0.3329 Generator Loss: 1.1163
# Epoch [7/10]                        Batch 700/1563 Discriminator Loss: 0.7399 Generator Loss: 1.2510
# Epoch [7/10]                        Batch 800/1563 Discriminator Loss: 0.7774 Generator Loss: 0.8336
# Epoch [7/10]                        Batch 900/1563 Discriminator Loss: 0.7176 Generator Loss: 0.8912
# Epoch [7/10]                        Batch 1000/1563 Discriminator Loss: 0.5563 Generator Loss: 1.8122
# Epoch [7/10]                        Batch 1100/1563 Discriminator Loss: 0.5330 Generator Loss: 1.3859
# Epoch [7/10]                        Batch 1200/1563 Discriminator Loss: 0.6624 Generator Loss: 0.8379
# Epoch [7/10]                        Batch 1300/1563 Discriminator Loss: 0.6353 Generator Loss: 0.8548
# Epoch [7/10]                        Batch 1400/1563 Discriminator Loss: 0.5129 Generator Loss: 1.6496
# Epoch [7/10]                        Batch 1500/1563 Discriminator Loss: 0.6946 Generator Loss: 0.6920
# Epoch [8/10]                        Batch 100/1563 Discriminator Loss: 0.7120 Generator Loss: 1.8218
# Epoch [8/10]                        Batch 200/1563 Discriminator Loss: 0.4715 Generator Loss: 1.2873
# Epoch [8/10]                        Batch 300/1563 Discriminator Loss: 0.5669 Generator Loss: 0.9643
# Epoch [8/10]                        Batch 400/1563 Discriminator Loss: 0.6313 Generator Loss: 1.5096
# Epoch [8/10]                        Batch 500/1563 Discriminator Loss: 0.6182 Generator Loss: 0.9681
# Epoch [8/10]                        Batch 600/1563 Discriminator Loss: 0.5470 Generator Loss: 1.2434
# Epoch [8/10]                        Batch 700/1563 Discriminator Loss: 0.5046 Generator Loss: 1.4868
# Epoch [8/10]                        Batch 800/1563 Discriminator Loss: 0.5376 Generator Loss: 1.3128
# Epoch [8/10]                        Batch 900/1563 Discriminator Loss: 0.7832 Generator Loss: 0.9232
# Epoch [8/10]                        Batch 1000/1563 Discriminator Loss: 0.5404 Generator Loss: 0.9283
# Epoch [8/10]                        Batch 1100/1563 Discriminator Loss: 0.6528 Generator Loss: 1.2077
# Epoch [8/10]                        Batch 1200/1563 Discriminator Loss: 0.5184 Generator Loss: 1.3938
# Epoch [8/10]                        Batch 1300/1563 Discriminator Loss: 0.5480 Generator Loss: 1.0062
# Epoch [8/10]                        Batch 1400/1563 Discriminator Loss: 0.5881 Generator Loss: 1.1417
# Epoch [8/10]                        Batch 1500/1563 Discriminator Loss: 0.7018 Generator Loss: 1.7334
# Epoch [9/10]                        Batch 100/1563 Discriminator Loss: 0.4218 Generator Loss: 1.3611
# Epoch [9/10]                        Batch 200/1563 Discriminator Loss: 0.7187 Generator Loss: 1.2888
# Epoch [9/10]                        Batch 300/1563 Discriminator Loss: 0.8134 Generator Loss: 0.9632
# Epoch [9/10]                        Batch 400/1563 Discriminator Loss: 0.6481 Generator Loss: 1.0402
# Epoch [9/10]                        Batch 500/1563 Discriminator Loss: 0.6350 Generator Loss: 1.2648
# Epoch [9/10]                        Batch 600/1563 Discriminator Loss: 0.5173 Generator Loss: 2.3281
# Epoch [9/10]                        Batch 700/1563 Discriminator Loss: 0.5096 Generator Loss: 1.0496
# Epoch [9/10]                        Batch 800/1563 Discriminator Loss: 0.5263 Generator Loss: 1.0209
# Epoch [9/10]                        Batch 900/1563 Discriminator Loss: 0.6497 Generator Loss: 1.5173
# Epoch [9/10]                        Batch 1000/1563 Discriminator Loss: 0.4287 Generator Loss: 1.1211
# Epoch [9/10]                        Batch 1100/1563 Discriminator Loss: 0.5285 Generator Loss: 1.4360
# Epoch [9/10]                        Batch 1200/1563 Discriminator Loss: 0.6096 Generator Loss: 0.7176
# Epoch [9/10]                        Batch 1300/1563 Discriminator Loss: 0.6672 Generator Loss: 1.1260
# Epoch [9/10]                        Batch 1400/1563 Discriminator Loss: 0.5947 Generator Loss: 2.5438
# Epoch [9/10]                        Batch 1500/1563 Discriminator Loss: 0.5753 Generator Loss: 0.8135
# Epoch [10/10]                        Batch 100/1563 Discriminator Loss: 0.6051 Generator Loss: 1.2071
# Epoch [10/10]                        Batch 200/1563 Discriminator Loss: 0.6440 Generator Loss: 1.0711
# Epoch [10/10]                        Batch 300/1563 Discriminator Loss: 0.6434 Generator Loss: 1.1224
# Epoch [10/10]                        Batch 400/1563 Discriminator Loss: 0.4906 Generator Loss: 1.3474
# Epoch [10/10]                        Batch 500/1563 Discriminator Loss: 0.5828 Generator Loss: 1.3273
# Epoch [10/10]                        Batch 600/1563 Discriminator Loss: 0.4794 Generator Loss: 1.4055
# Epoch [10/10]                        Batch 700/1563 Discriminator Loss: 0.5595 Generator Loss: 1.2478
